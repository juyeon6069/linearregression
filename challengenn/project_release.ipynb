# %% [markdown]
# **CSE 353 Project**
#
# In the following notebook you will encounter 5 challenge problems. The first three are binary classification problems in 2-D. The next one is your favorite MNIST 10-class classification. The final one is a regression problem over 2 features.
#
# Your challenge, should you choose to accept it, is to design neural networks to solve these problems. Your points will be calculated as follows.
#
#  - Binary classification: points(model) = -log10(misclassification), where misclassification is between 0 and 1
#  - K-class classification: points(model) = -log10(misclassification)
#  - Regression: points(model) = max(0,-log10) (MSE)
#
# Your challenge consists of 2 parts.
#
# Part 1: We evaluate your *fully trained* model.
# Part 2: We take a model you have given, + training code, and train it on a *slightly different dataset*. It will have similar properties, but the class labels will either be scrambled, or the features will be altered in some other way, so you cannot hope for a good score using your trained model. We will run your train code, with a time-out of 1 minute, and evaluate this model on our test set.
#
#
# The final scoring will be:
#
# points per challenge: 1/2 (  points(trained model over your train dataset) + points(trained model over your test dataset) + points(model + train code over my train set) + points(model + train code over my test set) ).
#
# Save your models as follows, inside a directory called 'models':
#
# challenge1a_trained.pkl, challenge1a_untrained.pkl,
# challenge1b_trained.pkl, challenge1b_untrained.pkl,
# challenge1c_trained.pkl, challenge1c_untrained.pkl,
# challenge2_trained.pkl, challenge2_untrained.pkl,
# challenge3_trained.pkl, challenge3_untrained.pkl
#
# where each pickle file is saved using
# pickle.dump(model,open('Challenge1a_trained.pkl','wb'))
#
# Make sure that your trained models have a command for inference, e.g. yhat = model.inference(X). See the test file to see how the models will be run.
#
# Save your train code so that I can call the commands
#
#     def master_train_model(probnum):
#         model = pickle.load(open('challenge%s_untrained.pkl' % probnum,'rb'))
#         model = train(model, probnum, Xtrain, ytrain) # you write the train function
#
# I should be able to access the `train` function after `from neuralNet import *`.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

import pickle 

from matplotlib import cm

# %%
def train_model(Xtrain, ytrain):

           
    return model

# This may help you with debugging
def plot_input_space(xlim, ylim,model,npoints,normalize = False):
    x = np.random.rand(npoints)*(xlim[1]-xlim[0])+xlim[0]
    y = np.random.rand(npoints)*(ylim[1]-ylim[0])+ylim[0]
    X = np.vstack([x,y])
    Xl = np.ones(npoints)[np.newaxis,:]
    loss,z = model.inference(X,Xl,soft = True) 
    if normalize:
        z = z + min(z)
        z = z / max(z)
    z = z[0]
    for t in range(npoints):
        c = z[t]
        
        
        plt.plot(x[t],y[t],'g.',alpha=c)
        plt.plot(x[t],y[t],'m.',alpha=1-c)

# %% [markdown]
# First challenge: Just your 2 everyday blobs (Binary classification)

# %%
data = pickle.load(  open('problems/challenge1a.pkl','rb'))
print(data.keys())
print(data['Xtrain'].shape,data['ytrain'].shape,data['Xtest'].shape,data['ytest'].shape)

plt.plot(data['Xtrain'][0,data['ytrain']==0],data['Xtrain'][1,data['ytrain']==0],'b.')
plt.plot(data['Xtrain'][0,data['ytrain']==1],data['Xtrain'][1,data['ytrain']==1],'r.')
# Out:
# dict_keys(['Xtrain', 'Xtest', 'ytrain', 'ytest'])
# (2, 5000) (5000,) (2, 5000) (5000,)

# %% [markdown]
# Second challenge: two concentric circles  (Binary classification)

# %%
data = pickle.load(  open('problems/challenge1b.pkl','rb'))

plt.plot(data['Xtrain'][0,data['ytrain']==0],data['Xtrain'][1,data['ytrain']==0],'b.')
plt.plot(data['Xtrain'][0,data['ytrain']==1],data['Xtrain'][1,data['ytrain']==1],'r.')

# %% [markdown]
# Third challenge: half moons! (Binary classification)

# %%
data = pickle.load(  open('problems/challenge1c.pkl','rb'))

plt.plot(data['Xtrain'][0,data['ytrain']==0],data['Xtrain'][1,data['ytrain']==0],'b.')
plt.plot(data['Xtrain'][0,data['ytrain']==1],data['Xtrain'][1,data['ytrain']==1],'r.')

# %% [markdown]
# Fourth challenge: MNIST.  (10-class classification)

# %%
data = pickle.load(  open('problems/challenge2.pkl','rb'))
print(data['Xtrain'].shape,data['ytrain'].shape,data['Xtest'].shape,data['ytest'].shape)
for k in range(9):
    plt.subplot(3,3,k+1)
    plt.imshow(np.reshape(data['Xtrain'][:,k],(28,28)))
    plt.title(np.argmax(data['ytrain'][:,k]))

plt.tight_layout()
# Out:
# (784, 60000) (10, 60000) (784, 10000) (10, 10000)

# %% [markdown]
# Fifth challenge: regression dataset. Can you guess what you are regressing?

# %%
data = pickle.load(  open('problems/challenge3.pkl','rb'))

print(data['Xtrain'].shape,data['ytrain'].shape,data['Xtest'].shape,data['ytest'].shape)
# Out:
# (2, 50000) (1, 50000) (2, 50000) (1, 50000)
